# %%
from importlib import reload
import load_data
reload(load_data)
from load_data import *


import numpy as np
from langdetect import detect
import translitcodec
import codecs

# %%
from unidecode import unidecode
unidecode("miś")
# Out:
# 'mis'

# %% [markdown]
# # Ostatecznie

# %%
from importlib import reload
import task1_work
reload(task1_work)
from task1_work import *

# %%
rank = fullTask(path1="data/title.akas.tsv.gz",
                path2="data/title.basics.tsv.gz",
                path3="data/title.ratings.tsv.gz",
                start = 2000, # rok rozpoczęcia analizy, domyślnie 1800
                end = 2020, # rok zakończenia analizy, domyślnie aktualny
                Ks = [5000], # filmów mających mniej niż K ocen nie bierzemy pod uwagę
                Ns = range(10, 201, 10), # do rankingu krajów bierzemy pod uwagę pierwsze N najlepszych filmów
                verbose = True, 
                file = "answer.txt" # do tego pliku zapiszą się hegemonie
)
# Out:
# Loading data...
# c:\Users\priva\OneDrive\Desktop\STUDIA\Narzędzia Informatyczne w Pythonie wspierające Analizę Danych\Projekt zaliczeniowy\load_data.py:25: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(path_to_file,
# Done!
# Preprocessing... Done!
# Creating ranking...
#
# Done!

# %%
rank
# Out:
# {5000: {10: ['Japan',
#    'Turkey',
#    'Bangladesh',
#    'Croatia',
#    'India',
#    'Iran, Islamic Republic of',
#    'Mexico',
#    'Poland'],
#   20: ['Turkey',
#    'Brazil',
#    'India',
#    'Iran, Islamic Republic of',
#    'Japan',
#    'Bangladesh',
#    'Croatia',
#    'South Korea',
#    'Mexico',
#    'Poland',
#    'Romania',
#    'South Africa'],
#   30: ['Turkey',
#    'South Korea',
#    'Romania',
#    'Brazil',
#    'France',
#    'India',
#    'Iran, Islamic Republic of',
#    'Japan',
#    'United Arab Emirates',
#    'Bangladesh',
#    'China',
#    'Croatia',
#    'Indonesia',
#    'Mexico',
#    'Poland',
#    'South Africa'],
#   40: ['Turkey',
#    'South Korea',
#    'Iran, Islamic Republic of',
#    'Romania',
#    'India',
#    'Japan',
#    'Brazil',
#    'France',
#    'Poland',
#    'Hungary',
#    'Mexico',
#    'United Arab Emirates',
#    'Bangladesh',
#    'Indonesia',
#    'Croatia',
#    'Denmark',
#    'China',
#    'South Africa'],
#   50: ['Turkey',
#    'South Korea',
#    'Iran, Islamic Republic of',
#    'Brazil',
#    'Romania',
#    'India',
#    'China',
#    'France',
#    'Poland',
#    'Hungary',
#    'Mexico',
#    'Japan',
#    'United Arab Emirates',
#    'Russian Federation',
#    'Indonesia',
#    'Bangladesh',
#    'Croatia',
#    'Denmark',
#    'Germany',
#    'Canada',
#    'South Africa'],
#   60: ['Turkey',
#    'Iran, Islamic Republic of',
#    'South Korea',
#    'Brazil',
#    'Romania',
#    'Japan',
#    'Germany',
#    'France',
#    'India',
#    'Hungary',
#    'China',
#    'Poland',
#    'Mexico',
#    'Russian Federation',
#    'United Arab Emirates',
#    'Indonesia',
#    'Bangladesh',
#    'Croatia',
#    'Finland',
#    'Egypt',
#    'Denmark',
#    'Canada',
#    'South Africa'],
#   70: ['Turkey',
#    'Iran, Islamic Republic of',
#    'South Korea',
#    'Germany',
#    'Japan',
#    'Romania',
#    'Brazil',
#    'France',
#    'India',
#    'China',
#    'Poland',
#    'Hungary',
#    'Mexico',
#    'Indonesia',
#    'Sweden',
#    'Russian Federation',
#    'Netherlands',
#    'United Arab Emirates',
#    'Israel',
#    'Bangladesh',
#    'Croatia',
#    'Hong Kong',
#    'Finland',
#    'Egypt',
#    'Denmark',
#    'Canada',
#    'South Africa'],
#   80: ['Turkey',
#    'Iran, Islamic Republic of',
#    'South Korea',
#    'Japan',
#    'Germany',
#    'Romania',
#    'Brazil',
#    'India',
#    'Hungary',
#    'France',
#    'Poland',
#    'Indonesia',
#    'Denmark',
#    'China',
#    'Mexico',
#    'Russian Federation',
#    'Sweden',
#    'Netherlands',
#    'United Arab Emirates',
#    'Israel',
#    'Italy',
#    'Bangladesh',
#    'Croatia',
#    'Hong Kong',
#    'Finland',
#    'Egypt',
#    'Canada',
#    'South Africa'],
#   90: ['Turkey',
#    'Iran, Islamic Republic of',
#    'Germany',
#    'South Korea',
#    'Romania',
#    'Brazil',
#    'Japan',
#    'India',
#    'Hungary',
#    'France',
#    'Denmark',
#    'Mexico',
#    'Poland',
#    'Indonesia',
#    'China',
#    'Italy',
#    'Norway',
#    'Russian Federation',
#    'Netherlands',
#    'Sweden',
#    'United Arab Emirates',
#    'Israel',
#    'Australia',
#    'Croatia',
#    'Hong Kong',
#    'Finland',
#    'Egypt',
#    'Canada',
#    'Bangladesh',
#    'South Africa'],
#   100: ['Turkey',
#    'Iran, Islamic Republic of',
#    'Germany',
#    'South Korea',
#    'Romania',
#    'Brazil',
#    'Hungary',
#    'Japan',
#    'India',
#    'Denmark',
#    'France',
#    'China',
#    'Egypt',
#    'Italy',
#    'Mexico',
#    'Poland',
#    'Indonesia',
#    'Russian Federation',
#    'United Arab Emirates',
#    'Norway',
#    'Sweden',
#    'Netherlands',
#    'Israel',
#    'Macedonia, The Former Yugoslav Republic of',
#    'Australia',
#    'Croatia',
#    'Hong Kong',
#    'Finland',
#    'Canada',
#    'Bangladesh',
#    'South Africa'],
#   110: ['Turkey',
#    'Germany',
#    'Iran, Islamic Republic of',
#    'Romania',
#    'South Korea',
#    'Hungary',
#    'Japan',
#    'Brazil',
#    'India',
#    'Denmark',
#    'France',
#    'China',
#    'Italy',
#    'Indonesia',
#    'Norway',
#    'Poland',
#    'Mexico',
#    'Russian Federation',
#    'Egypt',
#    'Sweden',
#    'Netherlands',
#    'United Arab Emirates',
#    'Israel',
#    'Macedonia, The Former Yugoslav Republic of',
#    'Australia',
#    'Croatia',
#    'Hong Kong',
#    'United Kingdom',
#    'Finland',
#    'Canada',
#    'Bangladesh',
#    'South Africa'],
#   120: ['Turkey',
#    'Germany',
#    'Iran, Islamic Republic of',
#    'South Korea',
#    'India',
#    'Romania',
#    'Hungary',
#    'Japan',
#    'Brazil',
#    'France',
#    'Denmark',
#    'Italy',
#    'Canada',
#    'Mexico',
#    'Egypt',
#    'Russian Federation',
#    'Poland',
#    'Norway',
#    'China',
#    'Indonesia',
#    'Sweden',
#    'Netherlands',
#    'Macedonia, The Former Yugoslav Republic of',
#    'United Arab Emirates',
#    'Israel',
#    'Iceland',
#    'Australia',
#    'Croatia',
#    'Hong Kong',
#    'United Kingdom',
#    'Finland',
#    'Czech Republic',
#    'Bangladesh',
#    'South Africa'],
#   130: ['Turkey',
#    'Germany',
#    'Iran, Islamic Republic of',
#    'India',
#    'South Korea',
#    'Romania',
#    'Japan',
#    'Brazil',
#    'Hungary',
#    'France',
#    'Italy',
#    'Russian Federation',
#    'Denmark',
#    'Mexico',
#    'Canada',
#    'Egypt',
#    'Poland',
#    'Norway',
#    'China',
#    'Indonesia',
#    'Netherlands',
#    'Macedonia, The Former Yugoslav Republic of',
#    'Sweden',
#    'United Arab Emirates',
#    'Iceland',
#    'Israel',
#    'Australia',
#    'Croatia',
#    'Hong Kong',
#    'Georgia',
#    'United Kingdom',
#    'Finland',
#    'Czech Republic',
#    'Bangladesh',
#    'South Africa'],
#   140: ['Turkey',
#    'Germany',
#    'Iran, Islamic Republic of',
#    'India',
#    'South Korea',
#    'Brazil',
#    'Romania',
#    'Japan',
#    'Hungary',
#    'Italy',
#    'France',
#    'Mexico',
#    'Russian Federation',
#    'Denmark',
#    'China',
#    'Canada',
#    'Poland',
#    'Norway',
#    'Egypt',
#    'Australia',
#    'Israel',
#    'Czech Republic',
#    'Indonesia',
#    'Sweden',
#    'Netherlands',
#    'United Arab Emirates',
#    'Macedonia, The Former Yugoslav Republic of',
#    'Iceland',
#    'Croatia',
#    'Hong Kong',
#    'Georgia',
#    'United Kingdom',
#    'Finland',
#    'Bangladesh',
#    'South Africa'],
#   150: ['Turkey',
#    'Germany',
#    'Iran, Islamic Republic of',
#    'South Korea',
#    'India',
#    'Romania',
#    'Brazil',
#    'Japan',
#    'Hungary',
#    'France',
#    'Italy',
#    'Norway',
#    'Indonesia',
#    'Mexico',
#    'Denmark',
#    'China',
#    'Canada',
#    'Russian Federation',
#    'Poland',
#    'Egypt',
#    'Australia',
#    'Israel',
#    'Czech Republic',
#    'Sweden',
#    'Netherlands',
#    'United Arab Emirates',
#    'Macedonia, The Former Yugoslav Republic of',
#    'Iceland',
#    'Croatia',
#    'Hong Kong',
#    'Georgia',
#    'United Kingdom',
#    'Finland',
#    'Bangladesh',
#    'South Africa'],
#   160: ['Turkey',
#    'Germany',
#    'South Korea',
#    'Iran, Islamic Republic of',
#    'India',
#    'Brazil',
#    'Romania',
#    'France',
#    'Japan',
#    'Italy',
#    'Hungary',
#    'Indonesia',
#    'Norway',
#    'Russian Federation',
#    'Denmark',
#    'China',
#    'Canada',
#    'Mexico',
#    'Hong Kong',
#    'Australia',
#    'Israel',
#    'Finland',
#    'Egypt',
#    'Poland',
#    'Czech Republic',
#    'Netherlands',
#    'Sweden',
#    'United Arab Emirates',
#    'Macedonia, The Former Yugoslav Republic of',
#    'Iceland',
#    'Croatia',
#    'Georgia',
#    'United Kingdom',
#    'Bangladesh',
#    'South Africa'],
#   170: ['Turkey',
#    'Germany',
#    'South Korea',
#    'Iran, Islamic Republic of',
#    'India',
#    'Brazil',
#    'France',
#    'Romania',
#    'Italy',
#    'Japan',
#    'Hungary',
#    'Indonesia',
#    'Poland',
#    'Russian Federation',
#    'Norway',
#    'Denmark',
#    'Czech Republic',
#    'China',
#    'Canada',
#    'Mexico',
#    'Hong Kong',
#    'Australia',
#    'Israel',
#    'Finland',
#    'Egypt',
#    'Iceland',
#    'Sweden',
#    'United Arab Emirates',
#    'Netherlands',
#    'Macedonia, The Former Yugoslav Republic of',
#    'Croatia',
#    'Georgia',
#    'United Kingdom',
#    'Bangladesh',
#    'South Africa'],
#   180: ['Turkey',
#    'Germany',
#    'South Korea',
#    'Iran, Islamic Republic of',
#    'India',
#    'France',
#    'Brazil',
#    'Italy',
#    'Romania',
#    'Hungary',
#    'Japan',
#    'Norway',
#    'Denmark',
#    'Israel',
#    'Mexico',
#    'Indonesia',
#    'Poland',
#    'Russian Federation',
#    'Czech Republic',
#    'China',
#    'Canada',
#    'Australia',
#    'Iceland',
#    'Finland',
#    'Egypt',
#    'Hong Kong',
#    'Sweden',
#    'Thailand',
#    'United Arab Emirates',
#    'Netherlands',
#    'Macedonia, The Former Yugoslav Republic of',
#    'Croatia',
#    'Georgia',
#    'United Kingdom',
#    'Bangladesh',
#    'South Africa'],
#   190: ['Turkey',
#    'Germany',
#    'South Korea',
#    'Iran, Islamic Republic of',
#    'India',
#    'Italy',
#    'France',
#    'Brazil',
#    'Romania',
#    'Japan',
#    'Norway',
#    'Hungary',
#    'Denmark',
#    'Czech Republic',
#    'Hong Kong',
#    'Russian Federation',
#    'Israel',
#    'Poland',
#    'Indonesia',
#    'China',
#    'Canada',
#    'Mexico',
#    'Australia',
#    'Finland',
#    'Iceland',
#    'Egypt',
#    'Sweden',
#    'Thailand',
#    'United Arab Emirates',
#    'Netherlands',
#    'Macedonia, The Former Yugoslav Republic of',
#    'Croatia',
#    'Georgia',
#    'United Kingdom',
#    'Spain',
#    'Bangladesh',
#    'South Africa'],
#   200: ['Turkey',
#    'South Korea',
#    'Germany',
#    'India',
#    'Iran, Islamic Republic of',
#    'Italy',
#    'France',
#    'Brazil',
#    'Romania',
#    'Japan',
#    'Hungary',
#    'Denmark',
#    'Norway',
#    'Czech Republic',
#    'Hong Kong',
#    'Russian Federation',
#    'Poland',
#    'Mexico',
#    'Iceland',
#    'Indonesia',
#    'Israel',
#    'China',
#    'Canada',
#    'Australia',
#    'Finland',
#    'Egypt',
#    'Netherlands',
#    'Sweden',
#    'Thailand',
#    'United Arab Emirates',
#    'Macedonia, The Former Yugoslav Republic of',
#    'Croatia',
#    'Georgia',
#    'United Kingdom',
#    'Spain',
#    'Bangladesh',
#    'South Africa'],
#   73423: ['Turkey',
#    'Germany',
#    'India',
#    'Italy',
#    'South Korea',
#    'France',
#    'Iran, Islamic Republic of',
#    'Canada',
#    'Japan',
#    'Denmark',
#    'Brazil',
#    'Spain',
#    'Norway',
#    'Romania',
#    'United States',
#    'Sweden',
#    'China',
#    'Iceland',
#    'Hungary',
#    'Poland',
#    'Russian Federation',
#    'Indonesia',
#    'Mexico',
#    'Hong Kong',
#    'Thailand',
#    'Finland',
#    'Czech Republic',
#    'Australia',
#    'United Kingdom',
#    'Israel',
#    'South Africa',
#    'Netherlands',
#    'Egypt',
#    'Belgium',
#    'Bangladesh',
#    'Macedonia, The Former Yugoslav Republic of',
#    'Argentina',
#    'Serbia',
#    'Croatia',
#    'Georgia',
#    'United Arab Emirates']}}

# %% [markdown]
# # 1. Standardowa analiza

# %%
path_to_file = "data/title.basics.tsv.gz"
df3 = load_to_dataframe(path_to_file)
# df3 = df3.loc[df3["startYear"].astype(int).between(1800, 2024), ["tconst", "titleType", "startYear"]]
# Out:
# c:\Users\priva\OneDrive\Desktop\STUDIA\Narzędzia Informatyczne w Pythonie wspierające Analizę Danych\Projekt zaliczeniowy\load_data.py:25: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(path_to_file,

# %%
df3.loc[df3["titleType"] == 'movie']
# Out:
#              tconst titleType  \
# 8         tt0000009     movie
# 144       tt0000147     movie
# 498       tt0000502     movie
# 570       tt0000574     movie
# 587       tt0000591     movie
# ...             ...       ...
# 10864942  tt9916622     movie
# 10864969  tt9916680     movie
# 10864981  tt9916706     movie
# 10864991  tt9916730     movie
# 10865001  tt9916754     movie
#
#                                                primaryTitle  \
# 8                                                Miss Jerry
# 144                           The Corbett-Fitzsimmons Fight
# 498                                                Bohemios
# 570                             The Story of the Kelly Gang
# 587                                        The Prodigal Son
# ...                                                     ...
# 10864942        Rodolpho Teóphilo - O Legado de um Pioneiro
# 10864969  De la ilusión al desconcierto: cine colombiano...
# 10864981                                    Dankyavar Danka
# 10864991                                             6 Gunn
# 10865001                     Chico Albuquerque - Revelações
#
#                                               originalTitle isAdult startYear  \
# 8                                                Miss Jerry       0      1894
# 144                           The Corbett-Fitzsimmons Fight       0      1897
# 498                                                Bohemios       0      1905
# 570                             The Story of the Kelly Gang       0      1906
# 587                                       L'enfant prodigue       0      1907
# ...                                                     ...     ...       ...
# 10864942        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 10864969  De la ilusión al desconcierto: cine colombiano...       0      2007
# 10864981                                    Dankyavar Danka       0      2013
# 10864991                                             6 Gunn       0      2017
# 10865001                     Chico Albuquerque - Revelações       0      2013
#
#          endYear runtimeMinutes                      genres
# 8           <NA>             45                     Romance
# 144         <NA>            100      Documentary,News,Sport
# 498         <NA>            100                        <NA>
# 570         <NA>             70  Action,Adventure,Biography
# 587         <NA>             90                       Drama
# ...          ...            ...                         ...
# 10864942    <NA>             57                 Documentary
# 10864969    <NA>            100                 Documentary
# 10864981    <NA>           <NA>                      Comedy
# 10864991    <NA>            116                       Drama
# 10865001    <NA>             49                 Documentary
#
# [684141 rows x 9 columns]

# %%
path_to_file = "data/title.akas.tsv.gz"
df1 = load_to_dataframe(path_to_file)
df1 = df1.drop(columns=["language", "types", "attributes"])

path_to_file = "data/title.basics.tsv.gz"
df3 = load_to_dataframe(path_to_file).dropna()
df3 = df3.loc[df3["startYear"].astype(int).between(1800, 2024), ["tconst", "titleType", "startYear"]]

path_to_file = "data/title.ratings.tsv.gz"
df7 = load_to_dataframe(path_to_file)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[49], line 2
#       1 path_to_file = "data/title.akas.tsv.gz"
# ----> 2 df1 = load_to_dataframe(path_to_file)
#       3 df1 = df1.drop(columns=["language", "types", "attributes"])
#       5 path_to_file = "data/title.basics.tsv.gz"
#
# File c:\Users\priva\OneDrive\Desktop\STUDIA\Narzędzia Informatyczne w Pythonie wspierające Analizę Danych\Projekt zaliczeniowy\load_data.py:25, in load_to_dataframe(path_to_file)
#      24 def load_to_dataframe(path_to_file: str) -> pd.DataFrame:
# ---> 25     return pd.read_csv(path_to_file,
#      26                        compression="gzip",
#      27                        header=0,
#      28                        sep="\t",
#      29                        on_bad_lines="warn").replace(to_replace=r"\N", value=pd.NA)
#
# File c:\Users\priva\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\priva\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\priva\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\priva\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608     return parser
#     610 with parser:
# --> 611     return parser.read(nrows)
#
# File c:\Users\priva\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1778, in TextFileReader.read(self, nrows)
#    1771 nrows = validate_integer("nrows", nrows)
#    1772 try:
#    1773     # error: "ParserBase" has no attribute "read"
#    1774     (
#    1775         index,
#    1776         columns,
#    1777         col_dict,
# -> 1778     ) = self._engine.read(  # type: ignore[attr-defined]
#    1779         nrows
#    1780     )
#    1781 except Exception:
#    1782     self.close()
#
# File c:\Users\priva\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:230, in CParserWrapper.read(self, nrows)
#     228 try:
#     229     if self.low_memory:
# --> 230         chunks = self._reader.read_low_memory(nrows)
#     231         # destructive to chunks
#     232         data = _concatenate_chunks(chunks)
#
# File c:\Users\priva\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\parsers.pyx:808, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File c:\Users\priva\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\parsers.pyx:866, in pandas._libs.parsers.TextReader._read_rows()
#
# File c:\Users\priva\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\parsers.pyx:852, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File c:\Users\priva\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\parsers.pyx:1973, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
df = df1.merge(df3,
              how="left",
              left_on="titleId",
              right_on="tconst"
)

# wybieramy tylko "movie" i niektóre kolumny
df = df.loc[df["titleType"] == "movie", ["titleId", "title", "region", "startYear", "isOriginalTitle"]]

# %%
# zamieniamy wszystkie tytuły na lowercase i dekodujemy narodowe znaki
df["title"] = df["title"].astype(str).str.lower().apply(lambda x: codecs.encode(str(x), 'translit/short'))

# wydostajemy kandydatów na filmy z których odzyskamy kraje
# zgodnie z uwagą w PDFie od prowadzących
df_think = df.loc[df["isOriginalTitle"] == 0].merge(
    df.loc[df["isOriginalTitle"] == 1],
    on="titleId",
    how="left",
    suffixes=("", "_y")
).query(
    "title == title_y"
).drop(
    labels=["title_y", "region_y", "startYear_y", "isOriginalTitle", "isOriginalTitle_y"],
    axis=1
)

# grupujemy po ID tytułu
# potem zliczamy ile było przypisanych regionów
# tam, gdzie był jeden, daje się zidentyfikować jednoznacznie
disambig = df_think.loc[:, ["titleId", "region"]].groupby(
    by=["titleId"]
).count()["region"] == 1

df_with_known_countries = df_think.loc[df_think["titleId"].isin(disambig.index[disambig == True])]

df_analysis = df_with_known_countries.merge(df7,
                                            how="left",
                                            left_on="titleId",
                                            right_on="tconst"
).drop(
    columns=["tconst"]
).dropna()

# %%
df_analysis
# Out:
#           titleId                          title region startYear  \
# 0       tt0000147  the corbett-fitzsimmons fight     US      1897
# 1       tt0000502                       bohemios     ES      1905
# 2       tt0000591              l'enfant prodigue     FR      1907
# 3       tt0000615             robbery under arms     AU      1907
# 4       tt0000630                         amleto     IT      1908
# ...           ...                            ...    ...       ...
# 460232  tt9916160                     drommeland     NL      2019
# 460234  tt9916170                       o ensaio     BR      2019
# 460237  tt9916270       il talento del calabrone     IT      2020
# 460238  tt9916538            kuambil lagi hatiku     ID      2019
# 460242  tt9916706                dankyavar danka     IN      2013
#
#         averageRating  numVotes
# 0                 5.2     517.0
# 1                 4.4      17.0
# 2                 5.7      25.0
# 3                 4.3      25.0
# 4                 2.9      27.0
# ...               ...       ...
# 460232            6.2      52.0
# 460234            7.0       7.0
# 460237            5.8    1488.0
# 460238            8.3       9.0
# 460242            7.6       5.0
#
# [151720 rows x 6 columns]

# %% [markdown]
# # 2. Model językowy

# %%
# wspieramy rozpoznawanie języka przez bibliotekę 'langdetect'
def mydetect(x):
    try:
        return detect(x).upper()
    except:
        return pd.NA

# funkcje do .apply()
def myfunc_EC(x):
    if x[5] != 'ES':
        x[2] = x[5]
    return x

def myfunc_TR(x):
    if x[5] != 'TR':
        x[2] = x[5]
    return x
    
# usuwamy dziwne filmy z Ekwadoru
df_EC = df_analysis.loc[df_analysis["region"] == 'EC'].copy()
df_EC.loc[:, "detected"] = df_EC["title"].apply(mydetect)

false_EC = df_EC.loc[df_EC["detected"] != 'ES']["titleId"]
df_EC = df_EC.apply(myfunc_EC, axis=1).drop(columns=["detected"])

df_analysis.loc[df_EC.index] = df_EC

# %% [markdown]
# # 3. Zasadnicza część zadania

# %%
from importlib import reload
import task1
reload(task1)
from task1 import *

# %%
df, df3 = load_dataframes(path1="data/title.akas.tsv.gz",
                            path2="data/title.basics.tsv.gz",
                            path3="data/title.ratings.tsv.gz")
# Out:
# c:\Users\priva\OneDrive\Desktop\STUDIA\Narzędzia Informatyczne w Pythonie wspierające Analizę Danych\Projekt zaliczeniowy\load_data.py:25: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(path_to_file,

# %%
df.head(10)
# Out:
#         titleId                          title region startYear  \
# 72    tt0000009                     Miss Jerry   <NA>      1894
# 73    tt0000009                     Miss Jerry     AU      1894
# 74    tt0000009                     Miss Jerry     HU      1894
# 75    tt0000009                     Miss Jerry     US      1894
# 76    tt0000009                 Fräulein Jerry     DE      1894
# 749   tt0000147  The Corbett-Fitzsimmons Fight   <NA>      1897
# 750   tt0000147  The Corbett-Fitzsimmons Fight     US      1897
# 751   tt0000147    Бой Корбетта и Фитцсиммонса     RU      1897
# 2045  tt0000502                       Bohemios   <NA>      1905
# 2046  tt0000502                       Bohemios     ES      1905
#
#       isOriginalTitle
# 72                  1
# 73                  0
# 74                  0
# 75                  0
# 76                  0
# 749                 1
# 750                 0
# 751                 0
# 2045                1
# 2046                0

# %%
df_analysis = prepareDataset(df, df3)

# %%
rank = answerRanks(df_analysis, Ks = [10, 100, 1000], Ns = range(10, 201, 10), file = "answer.txt")

# %%
rank
# Out:
# {10: {10: ['United States', 'Spain', 'India', 'Italy'],
#   20: ['United States',
#    'India',
#    'Spain',
#    'Thailand',
#    'Brazil',
#    'Italy',
#    'Norway'],
#   30: ['United States',
#    'India',
#    'Brazil',
#    'Spain',
#    'Thailand',
#    'United Kingdom',
#    'Italy',
#    'Mexico',
#    'Norway'],
#   40: ['United States',
#    'India',
#    'Thailand',
#    'Brazil',
#    'Spain',
#    'United Kingdom',
#    'Canada',
#    'Colombia',
#    'Iran, Islamic Republic of',
#    'Italy',
#    'Mexico',
#    'Norway'],
#   50: ['United States',
#    'India',
#    'Spain',
#    'Thailand',
#    'Brazil',
#    'United Kingdom',
#    'Italy',
#    'Canada',
#    'Colombia',
#    'Iran, Islamic Republic of',
#    'Mexico',
#    'Norway'],
#   60: ['United States',
#    'India',
#    'Brazil',
#    'Spain',
#    'Italy',
#    'Thailand',
#    'United Kingdom',
#    'Canada',
#    'Colombia',
#    'Iran, Islamic Republic of',
#    'Mexico',
#    'Norway',
#    'Sweden'],
#   70: ['United States',
#    'India',
#    'Brazil',
#    'Spain',
#    'Italy',
#    'Thailand',
#    'United Kingdom',
#    'Canada',
#    'Colombia',
#    'Iran, Islamic Republic of',
#    'Mexico',
#    'Norway',
#    'Sweden'],
#   80: ['United States',
#    'India',
#    'Brazil',
#    'Spain',
#    'Italy',
#    'Thailand',
#    'United Kingdom',
#    'Iran, Islamic Republic of',
#    'Canada',
#    'Colombia',
#    'Croatia',
#    'Mexico',
#    'Norway',
#    'Serbia',
#    'Sweden'],
#   90: ['United States',
#    'India',
#    'Brazil',
#    'Spain',
#    'Italy',
#    'Thailand',
#    'United Kingdom',
#    'Iran, Islamic Republic of',
#    'Canada',
#    'Colombia',
#    'Croatia',
#    'Mexico',
#    'Norway',
#    'Serbia',
#    'Sweden'],
#   100: ['United States',
#    'India',
#    'Brazil',
#    'Spain',
#    'United Kingdom',
#    'Italy',
#    'Thailand',
#    'Canada',
#    'Iran, Islamic Republic of',
#    'Colombia',
#    'Georgia',
#    'Croatia',
#    'Mexico',
#    'Norway',
#    'Serbia',
#    'Sweden'],
#   110: ['United States',
#    'India',
#    'Brazil',
#    'Spain',
#    'United Kingdom',
#    'Italy',
#    'Thailand',
#    'Germany',
#    'Canada',
#    'Mexico',
#    'Iran, Islamic Republic of',
#    'Georgia',
#    'Croatia',
#    'Colombia',
#    'Lithuania',
#    'Norway',
#    'Philippines',
#    'Serbia',
#    'Sweden'],
#   120: ['United States',
#    'India',
#    'Spain',
#    'Brazil',
#    'Thailand',
#    'United Kingdom',
#    'Italy',
#    'Mexico',
#    'Iran, Islamic Republic of',
#    'Germany',
#    'Canada',
#    'Indonesia',
#    'Croatia',
#    'Georgia',
#    'Japan',
#    'Lithuania',
#    'Colombia',
#    'Norway',
#    'Philippines',
#    'Serbia',
#    'Sweden',
#    'Bulgaria'],
#   130: ['United States',
#    'India',
#    'Brazil',
#    'Spain',
#    'United Kingdom',
#    'Thailand',
#    'Germany',
#    'Italy',
#    'Serbia',
#    'Mexico',
#    'Iran, Islamic Republic of',
#    'Indonesia',
#    'Canada',
#    'Bulgaria',
#    'Croatia',
#    'Japan',
#    'Lithuania',
#    'Georgia',
#    'Nigeria',
#    'Norway',
#    'Philippines',
#    'Puerto Rico',
#    'Colombia',
#    'Sweden',
#    'Australia'],
#   140: ['United States',
#    'India',
#    'Spain',
#    'United Kingdom',
#    'Brazil',
#    'Thailand',
#    'Indonesia',
#    'Italy',
#    'Germany',
#    'Canada',
#    'Iran, Islamic Republic of',
#    'Japan',
#    'Serbia',
#    'Mexico',
#    'Georgia',
#    'Philippines',
#    'Sweden',
#    'Puerto Rico',
#    'Poland',
#    'Nigeria',
#    'Norway',
#    'Croatia',
#    'Lithuania',
#    'Bulgaria',
#    'Colombia',
#    'Australia'],
#   150: ['United States',
#    'India',
#    'Spain',
#    'Italy',
#    'Brazil',
#    'Thailand',
#    'United Kingdom',
#    'Germany',
#    'Indonesia',
#    'Japan',
#    'Serbia',
#    'Mexico',
#    'Australia',
#    'Iran, Islamic Republic of',
#    'Canada',
#    'Bulgaria',
#    'Lithuania',
#    'Croatia',
#    'Nigeria',
#    'Norway',
#    'Philippines',
#    'Poland',
#    'Puerto Rico',
#    'Georgia',
#    'Sweden',
#    'Colombia',
#    'South Africa'],
#   160: ['United States',
#    'India',
#    'Spain',
#    'Italy',
#    'Brazil',
#    'Thailand',
#    'United Kingdom',
#    'Germany',
#    'Serbia',
#    'Indonesia',
#    'Iran, Islamic Republic of',
#    'Japan',
#    'Mexico',
#    'Australia',
#    'Croatia',
#    'Canada',
#    'Bulgaria',
#    'Lithuania',
#    'Nigeria',
#    'Norway',
#    'Philippines',
#    'Poland',
#    'Puerto Rico',
#    'Georgia',
#    'Sweden',
#    'Colombia',
#    'South Africa'],
#   170: ['United States',
#    'India',
#    'United Kingdom',
#    'Spain',
#    'Italy',
#    'Brazil',
#    'Thailand',
#    'Germany',
#    'Iran, Islamic Republic of',
#    'Serbia',
#    'Indonesia',
#    'Mexico',
#    'Japan',
#    'Australia',
#    'Croatia',
#    'Canada',
#    'Bulgaria',
#    'Lithuania',
#    'Greece',
#    'Nigeria',
#    'Norway',
#    'Philippines',
#    'Poland',
#    'Puerto Rico',
#    'Georgia',
#    'Sweden',
#    'Colombia',
#    'South Africa'],
#   180: ['United States',
#    'India',
#    'United Kingdom',
#    'Brazil',
#    'Spain',
#    'Thailand',
#    'Italy',
#    'Germany',
#    'Iran, Islamic Republic of',
#    'Serbia',
#    'Indonesia',
#    'Mexico',
#    'Lithuania',
#    'Japan',
#    'Australia',
#    'Croatia',
#    'Canada',
#    'Bosnia and Herzegovina',
#    'Greece',
#    'Georgia',
#    'France',
#    'Nigeria',
#    'Norway',
#    'Philippines',
#    'Poland',
#    'Puerto Rico',
#    'Colombia',
#    'Sweden',
#    'Bulgaria',
#    'South Africa'],
#   190: ['United States',
#    'India',
#    'United Kingdom',
#    'Brazil',
#    'Spain',
#    'Thailand',
#    'Italy',
#    'Germany',
#    'Iran, Islamic Republic of',
#    'Serbia',
#    'Indonesia',
#    'Philippines',
#    'Mexico',
#    'Lithuania',
#    'Japan',
#    'Australia',
#    'Croatia',
#    'Canada',
#    'Bosnia and Herzegovina',
#    'Greece',
#    'Ghana',
#    'Georgia',
#    'Nigeria',
#    'Norway',
#    'France',
#    'Poland',
#    'Puerto Rico',
#    'Portugal',
#    'Colombia',
#    'Sweden',
#    'Bulgaria',
#    'South Africa'],
#   200: ['United States',
#    'India',
#    'United Kingdom',
#    'Brazil',
#    'Spain',
#    'Italy',
#    'Thailand',
#    'Germany',
#    'Iran, Islamic Republic of',
#    'Canada',
#    'Serbia',
#    'Indonesia',
#    'Philippines',
#    'Mexico',
#    'Lithuania',
#    'Japan',
#    'Australia',
#    'Croatia',
#    'Bosnia and Herzegovina',
#    'Greece',
#    'Ghana',
#    'Nigeria',
#    'Norway',
#    'Georgia',
#    'Poland',
#    'Puerto Rico',
#    'Portugal',
#    'France',
#    'Sweden',
#    'Colombia',
#    'Bulgaria',
#    'South Africa'],
#   146177: ['United States',
#    'India',
#    'Italy',
#    'France',
#    'United Kingdom',
#    'Germany',
#    'Turkey',
#    'Spain',
#    'Brazil',
#    'Mexico',
#    'Canada',
#    'Argentina',
#    'Iran, Islamic Republic of',
#    'Sweden',
#    'Egypt',
#    'South Korea',
#    'Poland',
#    'Japan',
#    'Philippines',
#    'Hungary',
#    'Netherlands',
#    'Denmark',
#    'Indonesia',
#    'China',
#    'Australia',
#    'Romania',
#    'Finland',
#    'Norway',
#    'Austria',
#    'Hong Kong',
#    'Czech Republic',
#    'Portugal',
#    'Israel',
#    'Switzerland',
#    'Malaysia',
#    'Belgium',
#    'Thailand',
#    'Bangladesh',
#    'Chile',
#    'South Africa',
#    'Croatia',
#    'Greece',
#    'Pakistan',
#    'Colombia',
#    'Serbia',
#    'Slovenia',
#    'Sri Lanka',
#    'Iceland',
#    'Estonia',
#    'Nepal',
#    'Latvia',
#    'Ireland',
#    'Venezuela, Bolivarian Republic of',
#    'Singapore',
#    'Peru',
#    'Dominican Republic',
#    'Lithuania',
#    'Albania',
#    'Slovakia',
#    'Georgia',
#    'Lebanon',
#    'Cuba',
#    'New Zealand',
#    'Kazakhstan',
#    'Puerto Rico',
#    'Morocco',
#    'Ukraine',
#    'Armenia',
#    'Russian Federation',
#    'Azerbaijan',
#    'Uruguay',
#    'Nigeria',
#    'Bosnia and Herzegovina',
#    'Tunisia',
#    'Algeria',
#    'Costa Rica',
#    'Viet Nam',
#    'United Arab Emirates',
#    'Bolivia',
#    'Syrian Arab Republic',
#    'Luxembourg',
#    'Belarus',
#    'Iraq',
#    'Cyprus',
#    'Macedonia, The Former Yugoslav Republic of',
#    'Bulgaria',
#    'Mongolia',
#    'Saudi Arabia',
#    'Uzbekistan',
#    'North Korea',
#    'Panama',
#    'Guatemala',
#    'Yugoslavia',
#    'Cambodia',
#    'Kuwait',
#    'Kyrgyzstan',
#    'Senegal',
#    'Paraguay',
#    'Afghanistan',
#    'Malta',
#    'Tanzania, United Republic of',
#    'Honduras',
#    'Kenya',
#    'Moldova',
#    'Burkina Faso',
#    'Jordan',
#    'San Marino',
#    'Qatar',
#    'Bahrain',
#    'Myanmar',
#    'Ghana',
#    'El Salvador',
#    'Mali',
#    'Cameroon',
#    'Niger',
#    'Montenegro',
#    'Angola',
#    'Haiti',
#    'Uganda',
#    "Côte d'Ivoire",
#    'Maldives',
#    'Ethiopia',
#    'Trinidad and Tobago',
#    'Greenland',
#    "Lao People's Democratic Republic",
#    'Zimbabwe',
#    'Bhutan',
#    'Mozambique',
#    'Jamaica',
#    'Rwanda',
#    'Congo, The Democratic Republic of the',
#    'Nicaragua',
#    'Mauritius',
#    'Tajikistan',
#    'Macao',
#    'Sierra Leone',
#    'Chad',
#    'Turkmenistan',
#    'Suriname',
#    'Gabon',
#    'Marshall Islands',
#    'Benin',
#    'Oman',
#    'Liechtenstein',
#    'Brunei',
#    'Cape Verde',
#    'Sudan',
#    'Guinea-Bissau',
#    'Malawi',
#    'Faroe Islands',
#    'Bahamas',
#    'Congo',
#    'Barbados',
#    'Antigua and Barbuda',
#    'Belize',
#    'Somalia',
#    'Mauritania',
#    'Papua New Guinea',
#    'Guam',
#    'New Caledonia',
#    'Saint Lucia',
#    'Aruba',
#    'Yemen',
#    'French Polynesia',
#    'Virgin Islands, U.S.',
#    'Vatican City',
#    'Martinique',
#    'Madagascar',
#    'Monaco',
#    'Lesotho',
#    'Liberia',
#    'Isle of Man',
#    'Sao Tome and Principe',
#    'Djibouti',
#    'Tonga',
#    'Eritrea',
#    'Timor-Leste',
#    'Equatorial Guinea',
#    'Fiji',
#    'Togo',
#    'Guinea',
#    'Swaziland',
#    'Gibraltar',
#    'Grenada',
#    'Andorra']},
#  100: {10: ['India', 'United States'],
#   20: ['India',
#    'Bosnia and Herzegovina',
#    'United States',
#    'Germany',
#    'Spain',
#    'Serbia'],
#   30: ['India',
#    'United States',
#    'Bosnia and Herzegovina',
#    'Serbia',
#    'Germany',
#    'Spain',
#    'United Kingdom'],
#   40: ['India',
#    'United States',
#    'United Kingdom',
#    'Bosnia and Herzegovina',
#    'Serbia',
#    'Brazil',
#    'Germany',
#    'Spain',
#    'Myanmar'],
#   50: ['India',
#    'United States',
#    'United Kingdom',
#    'Bosnia and Herzegovina',
#    'Serbia',
#    'Albania',
#    'Bangladesh',
#    'Brazil',
#    'Costa Rica',
#    'Germany',
#    'Spain',
#    'Iraq',
#    'South Korea',
#    'Myanmar'],
#   60: ['India',
#    'United States',
#    'United Kingdom',
#    'Bosnia and Herzegovina',
#    'Serbia',
#    'Albania',
#    'Bangladesh',
#    'Brazil',
#    'Costa Rica',
#    'Germany',
#    'Spain',
#    'Iraq',
#    'Italy',
#    'South Korea',
#    'Myanmar'],
#   70: ['India',
#    'United States',
#    'United Kingdom',
#    'Bosnia and Herzegovina',
#    'Serbia',
#    'Albania',
#    'Argentina',
#    'Bangladesh',
#    'Brazil',
#    'Costa Rica',
#    'Germany',
#    'Spain',
#    'Iraq',
#    'Italy',
#    'South Korea',
#    'Myanmar'],
#   80: ['India',
#    'United States',
#    'United Kingdom',
#    'Bangladesh',
#    'Bosnia and Herzegovina',
#    'Serbia',
#    'Bulgaria',
#    'Brazil',
#    'Costa Rica',
#    'Germany',
#    'Spain',
#    'Argentina',
#    'Iraq',
#    'Italy',
#    'South Korea',
#    'Macedonia, The Former Yugoslav Republic of',
#    'Myanmar',
#    'Albania'],
#   90: ['India',
#    'United States',
#    'United Kingdom',
#    'Bangladesh',
#    'South Korea',
#    'Serbia',
#    'Bosnia and Herzegovina',
#    'Costa Rica',
#    'Germany',
#    'Spain',
#    'Argentina',
#    'Bulgaria',
#    'Iraq',
#    'Italy',
#    'Canada',
#    'Macedonia, The Former Yugoslav Republic of',
#    'Myanmar',
#    'Romania',
#    'Brazil',
#    'Albania'],
#   100: ['India',
#    'United States',
#    'United Kingdom',
#    'Bangladesh',
#    'South Korea',
#    'Serbia',
#    'Italy',
#    'Bosnia and Herzegovina',
#    'Iran, Islamic Republic of',
#    'Romania',
#    'Myanmar',
#    'Macedonia, The Former Yugoslav Republic of',
#    'Iraq',
#    'Bulgaria',
#    'Argentina',
#    'Spain',
#    'Germany',
#    'Costa Rica',
#    'Canada',
#    'Brazil',
#    'Albania'],
#   110: ['India',
#    'United States',
#    'United Kingdom',
#    'Bangladesh',
#    'Serbia',
#    'South Korea',
#    'Italy',
#    'Bosnia and Herzegovina',
#    'Iran, Islamic Republic of',
#    'Romania',
#    'Myanmar',
#    'Macedonia, The Former Yugoslav Republic of',
#    'Iraq',
#    'Bulgaria',
#    'Argentina',
#    'Spain',
#    'Germany',
#    'Costa Rica',
#    'Canada',
#    'Brazil',
#    'Albania'],
#   120: ['India',
#    'United States',
#    'United Kingdom',
#    'Serbia',
#    'Bangladesh',
#    'South Korea',
#    'Italy',
#    'Albania',
#    'Bosnia and Herzegovina',
#    'Costa Rica',
#    'Germany',
#    'Algeria',
#    'Argentina',
#    'Canada',
#    'Brazil',
#    'Iraq',
#    'Iran, Islamic Republic of',
#    'Bahrain',
#    'Bulgaria',
#    'Macedonia, The Former Yugoslav Republic of',
#    'Myanmar',
#    'Romania',
#    'Spain'],
#   130: ['India',
#    'United States',
#    'United Kingdom',
#    'Bangladesh',
#    'Serbia',
#    'South Korea',
#    'Italy',
#    'Albania',
#    'Bosnia and Herzegovina',
#    'Costa Rica',
#    'Germany',
#    'Turkey',
#    'Romania',
#    'Norway',
#    'Myanmar',
#    'Macedonia, The Former Yugoslav Republic of',
#    'Bulgaria',
#    'Bahrain',
#    'Iran, Islamic Republic of',
#    'Iraq',
#    'Brazil',
#    'Argentina',
#    'Canada',
#    'Spain',
#    'Algeria',
#    'Hungary'],
#   140: ['India',
#    'United States',
#    'United Kingdom',
#    'Bangladesh',
#    'Serbia',
#    'South Korea',
#    'Italy',
#    'Bosnia and Herzegovina',
#    'Albania',
#    'Germany',
#    'Macedonia, The Former Yugoslav Republic of',
#    'Turkey',
#    'Bulgaria',
#    'Romania',
#    'Portugal',
#    'Pakistan',
#    'Norway',
#    'Myanmar',
#    'Bahrain',
#    'Algeria',
#    'Brazil',
#    'Iran, Islamic Republic of',
#    'Canada',
#    'Argentina',
#    'Hungary',
#    'Costa Rica',
#    'Spain',
#    'Iraq'],
#   150: ['India',
#    'United States',
#    'United Kingdom',
#    'Bangladesh',
#    'Serbia',
#    'South Korea',
#    'Italy',
#    'Bosnia and Herzegovina',
#    'Iran, Islamic Republic of',
#    'Albania',
#    'Algeria',
#    'Spain',
#    'Turkey',
#    'Bulgaria',
#    'Romania',
#    'Portugal',
#    'Pakistan',
#    'Norway',
#    'Myanmar',
#    'Macedonia, The Former Yugoslav Republic of',
#    'Bahrain',
#    'Brazil',
#    'Canada',
#    'Costa Rica',
#    'Argentina',
#    'Hungary',
#    'Germany',
#    'Iraq'],
#   160: ['India',
#    'United States',
#    'United Kingdom',
#    'Bangladesh',
#    'Serbia',
#    'South Korea',
#    'Italy',
#    'Turkey',
#    'Iran, Islamic Republic of',
#    'Albania',
#    'Bosnia and Herzegovina',
#    'Canada',
#    'Denmark',
#    'Macedonia, The Former Yugoslav Republic of',
#    'Bulgaria',
#    'Romania',
#    'Portugal',
#    'Pakistan',
#    'Norway',
#    'Myanmar',
#    'Bahrain',
#    'Algeria',
#    'Brazil',
#    'Iraq',
#    'Costa Rica',
#    'Argentina',
#    'Germany',
#    'Spain',
#    'Hungary'],
#   170: ['India',
#    'United States',
#    'United Kingdom',
#    'Bangladesh',
#    'Turkey',
#    'Serbia',
#    'South Korea',
#    'Italy',
#    'Bosnia and Herzegovina',
#    'Iran, Islamic Republic of',
#    'Albania',
#    'Canada',
#    'Algeria',
#    'Macedonia, The Former Yugoslav Republic of',
#    'Bulgaria',
#    'Bahrain',
#    'Romania',
#    'Portugal',
#    'Pakistan',
#    'Norway',
#    'Myanmar',
#    'Latvia',
#    'Spain',
#    'Brazil',
#    'Costa Rica',
#    'Germany',
#    'Argentina',
#    'Hungary',
#    'Denmark',
#    'Iraq'],
#   180: ['India',
#    'United States',
#    'United Kingdom',
#    'Bangladesh',
#    'South Korea',
#    'Turkey',
#    'Serbia',
#    'Italy',
#    'Canada',
#    'Iran, Islamic Republic of',
#    'Bosnia and Herzegovina',
#    'Albania',
#    'Hungary',
#    'Argentina',
#    'Myanmar',
#    'Netherlands',
#    'Macedonia, The Former Yugoslav Republic of',
#    'Pakistan',
#    'Portugal',
#    'Romania',
#    'Norway',
#    'Iraq',
#    'Latvia',
#    'Spain',
#    'Algeria',
#    'Denmark',
#    'Germany',
#    'Costa Rica',
#    'Brazil',
#    'Bahrain',
#    'Bulgaria',
#    'United Arab Emirates'],
#   190: ['India',
#    'United States',
#    'United Kingdom',
#    'Bangladesh',
#    'Turkey',
#    'Serbia',
#    'South Korea',
#    'Italy',
#    'Hungary',
#    'Bosnia and Herzegovina',
#    'Romania',
#    'Canada',
#    'Iran, Islamic Republic of',
#    'Albania',
#    'Algeria',
#    'Norway',
#    'Netherlands',
#    'Macedonia, The Former Yugoslav Republic of',
#    'Philippines',
#    'Pakistan',
#    'Portugal',
#    'Myanmar',
#    'United Arab Emirates',
#    'Latvia',
#    'Lithuania',
#    'Spain',
#    'Denmark',
#    'Germany',
#    'Costa Rica',
#    'Brazil',
#    'Bahrain',
#    'Bulgaria',
#    'Argentina',
#    'Iraq'],
#   200: ['India',
#    'United States',
#    'United Kingdom',
#    'Bangladesh',
#    'Turkey',
#    'Italy',
#    'Serbia',
#    'South Korea',
#    'Hungary',
#    'Bosnia and Herzegovina',
#    'Romania',
#    'Canada',
#    'Iran, Islamic Republic of',
#    'Albania',
#    'Algeria',
#    'Norway',
#    'Netherlands',
#    'Macedonia, The Former Yugoslav Republic of',
#    'Philippines',
#    'Pakistan',
#    'Portugal',
#    'Myanmar',
#    'United Arab Emirates',
#    'Latvia',
#    'Lithuania',
#    'Spain',
#    'Denmark',
#    'Germany',
#    'Costa Rica',
#    'Brazil',
#    'Bahrain',
#    'Bulgaria',
#    'Argentina',
#    'Iraq'],
#   146177: ['United States',
#    'India',
#    'Italy',
#    'France',
#    'Germany',
#    'Turkey',
#    'United Kingdom',
#    'Spain',
#    'Brazil',
#    'South Korea',
#    'Iran, Islamic Republic of',
#    'Canada',
#    'Sweden',
#    'Egypt',
#    'Poland',
#    'Japan',
#    'Denmark',
#    'Netherlands',
#    'Mexico',
#    'Hungary',
#    'Indonesia',
#    'Norway',
#    'Argentina',
#    'Romania',
#    'Hong Kong',
#    'Finland',
#    'Czech Republic',
#    'Philippines',
#    'China',
#    'Australia',
#    'Portugal',
#    'Thailand',
#    'Belgium',
#    'Austria',
#    'Israel',
#    'Croatia',
#    'Bangladesh',
#    'Serbia',
#    'Iceland',
#    'Chile',
#    'Estonia',
#    'Colombia',
#    'Switzerland',
#    'South Africa',
#    'Malaysia',
#    'Lithuania',
#    'Singapore',
#    'Slovenia',
#    'Greece',
#    'Latvia',
#    'Pakistan',
#    'Georgia',
#    'Sri Lanka',
#    'Peru',
#    'Dominican Republic',
#    'Lebanon',
#    'Slovakia',
#    'Venezuela, Bolivarian Republic of',
#    'Bosnia and Herzegovina',
#    'Nepal',
#    'Ukraine',
#    'Russian Federation',
#    'United Arab Emirates',
#    'Cuba',
#    'Costa Rica',
#    'Macedonia, The Former Yugoslav Republic of',
#    'Puerto Rico',
#    'Azerbaijan',
#    'Kazakhstan',
#    'Albania',
#    'Yugoslavia',
#    'New Zealand',
#    'Uruguay',
#    'Ireland',
#    'Bolivia',
#    'Iraq',
#    'Luxembourg',
#    'Saudi Arabia',
#    'Armenia',
#    'Algeria',
#    'Viet Nam',
#    'Syrian Arab Republic',
#    'Bulgaria',
#    'Malta',
#    'Cyprus',
#    'Myanmar',
#    'Morocco',
#    'Senegal',
#    'Kyrgyzstan',
#    'North Korea',
#    'Tunisia',
#    'Cambodia',
#    'Mongolia',
#    'Greenland',
#    'Afghanistan',
#    'Uzbekistan',
#    'Kuwait',
#    'Jordan',
#    'Belarus',
#    'Bhutan',
#    'Tajikistan',
#    'Haiti',
#    'Guatemala',
#    'Mali',
#    'Panama',
#    'Cameroon',
#    'Moldova',
#    'Chad',
#    "Lao People's Democratic Republic",
#    'Honduras',
#    'Burkina Faso',
#    'Montenegro',
#    'Ghana',
#    'Ethiopia',
#    'Nigeria',
#    'Yemen',
#    'Trinidad and Tobago',
#    'Tanzania, United Republic of',
#    'Kenya',
#    'Suriname',
#    'Sudan',
#    'Niger',
#    'Mozambique',
#    'Liechtenstein',
#    'Jamaica',
#    'Guinea-Bissau',
#    'Gibraltar',
#    "Côte d'Ivoire",
#    'Bahamas',
#    'Brunei',
#    'Bahrain',
#    'Angola',
#    'Zimbabwe']},
#  1000: {10: ['India', 'Bangladesh', 'Turkey'],
#   20: ['India', 'Bangladesh', 'Turkey', 'Canada', 'Latvia'],
#   30: ['India',
#    'Turkey',
#    'Bangladesh',
#    'Hungary',
#    'Latvia',
#    'Romania',
#    'Canada'],
#   40: ['India',
#    'Turkey',
#    'Bangladesh',
#    'Hungary',
#    'Romania',
#    'Latvia',
#    'Canada',
#    'Yugoslavia'],
#   50: ['India',
#    'Turkey',
#    'Bangladesh',
#    'Romania',
#    'Hungary',
#    'Latvia',
#    'Canada',
#    'Germany',
#    'Georgia',
#    'Yugoslavia'],
#   60: ['India',
#    'Turkey',
#    'Bangladesh',
#    'Romania',
#    'Hungary',
#    'Latvia',
#    'Canada',
#    'Germany',
#    'Georgia',
#    'Croatia',
#    'United States',
#    'Yugoslavia'],
#   70: ['India',
#    'Turkey',
#    'Romania',
#    'Bangladesh',
#    'Hungary',
#    'Latvia',
#    'Canada',
#    'Germany',
#    'Georgia',
#    'Croatia',
#    'Mexico',
#    'Ukraine',
#    'United States',
#    'Yugoslavia'],
#   80: ['India',
#    'Turkey',
#    'Romania',
#    'Bangladesh',
#    'Hungary',
#    'Latvia',
#    'Yugoslavia',
#    'Canada',
#    'Germany',
#    'Georgia',
#    'Croatia',
#    'Japan',
#    'Mexico',
#    'Poland',
#    'Ukraine',
#    'United States'],
#   90: ['India',
#    'Turkey',
#    'Romania',
#    'Bangladesh',
#    'Hungary',
#    'United States',
#    'Latvia',
#    'Yugoslavia',
#    'Croatia',
#    'Georgia',
#    'Brazil',
#    'France',
#    'Mexico',
#    'Pakistan',
#    'Poland',
#    'Egypt',
#    'Germany',
#    'Ukraine',
#    'Canada',
#    'Japan'],
#   100: ['India',
#    'Turkey',
#    'Romania',
#    'Bangladesh',
#    'Hungary',
#    'United States',
#    'Latvia',
#    'Japan',
#    'Yugoslavia',
#    'Canada',
#    'Croatia',
#    'Georgia',
#    'Brazil',
#    'Italy',
#    'France',
#    'Egypt',
#    'Mexico',
#    'Pakistan',
#    'Poland',
#    'Germany',
#    'China',
#    'Ukraine',
#    'Iran, Islamic Republic of'],
#   110: ['India',
#    'Turkey',
#    'Romania',
#    'Bangladesh',
#    'Hungary',
#    'United States',
#    'Japan',
#    'Latvia',
#    'Yugoslavia',
#    'Egypt',
#    'Canada',
#    'Croatia',
#    'Georgia',
#    'United Kingdom',
#    'Brazil',
#    'Italy',
#    'France',
#    'Mexico',
#    'Pakistan',
#    'Poland',
#    'Germany',
#    'China',
#    'Ukraine',
#    'Iran, Islamic Republic of'],
#   120: ['India',
#    'Turkey',
#    'Bangladesh',
#    'Romania',
#    'Hungary',
#    'United States',
#    'Canada',
#    'Latvia',
#    'Japan',
#    'Italy',
#    'Brazil',
#    'Yugoslavia',
#    'Egypt',
#    'Croatia',
#    'Georgia',
#    'United Kingdom',
#    'France',
#    'Mexico',
#    'Pakistan',
#    'Poland',
#    'Sweden',
#    'Germany',
#    'Ukraine',
#    'China',
#    'Iran, Islamic Republic of'],
#   130: ['India',
#    'Turkey',
#    'Bangladesh',
#    'Romania',
#    'Hungary',
#    'Japan',
#    'United States',
#    'Italy',
#    'Latvia',
#    'Canada',
#    'Yugoslavia',
#    'Poland',
#    'Egypt',
#    'Brazil',
#    'Pakistan',
#    'Ukraine',
#    'Sweden',
#    'Bosnia and Herzegovina',
#    'Mexico',
#    'Croatia',
#    'Georgia',
#    'United Kingdom',
#    'France',
#    'Germany',
#    'China',
#    'Iran, Islamic Republic of'],
#   140: ['India',
#    'Turkey',
#    'Romania',
#    'Bangladesh',
#    'Hungary',
#    'Japan',
#    'United States',
#    'Italy',
#    'Canada',
#    'Latvia',
#    'Iran, Islamic Republic of',
#    'Poland',
#    'Mexico',
#    'Yugoslavia',
#    'Egypt',
#    'Brazil',
#    'Croatia',
#    'Georgia',
#    'United Kingdom',
#    'France',
#    'Pakistan',
#    'Germany',
#    'Sweden',
#    'China',
#    'Ukraine',
#    'Bosnia and Herzegovina'],
#   150: ['India',
#    'Turkey',
#    'Romania',
#    'Hungary',
#    'Bangladesh',
#    'United States',
#    'Italy',
#    'Japan',
#    'Iran, Islamic Republic of',
#    'Canada',
#    'Latvia',
#    'Sweden',
#    'Poland',
#    'Mexico',
#    'Yugoslavia',
#    'Egypt',
#    'Brazil',
#    'Croatia',
#    'Georgia',
#    'United Kingdom',
#    'Pakistan',
#    'France',
#    'Germany',
#    'China',
#    'Ukraine',
#    'Bosnia and Herzegovina'],
#   160: ['India',
#    'Turkey',
#    'Romania',
#    'United States',
#    'Hungary',
#    'Bangladesh',
#    'Japan',
#    'Italy',
#    'Iran, Islamic Republic of',
#    'Brazil',
#    'Canada',
#    'Latvia',
#    'Sweden',
#    'Poland',
#    'Mexico',
#    'Yugoslavia',
#    'United Kingdom',
#    'Egypt',
#    'Croatia',
#    'Georgia',
#    'Pakistan',
#    'France',
#    'Germany',
#    'Ukraine',
#    'China',
#    'Bosnia and Herzegovina'],
#   170: ['India',
#    'Turkey',
#    'Romania',
#    'Hungary',
#    'Bangladesh',
#    'United States',
#    'Italy',
#    'Japan',
#    'Iran, Islamic Republic of',
#    'Brazil',
#    'Canada',
#    'Latvia',
#    'United Kingdom',
#    'Mexico',
#    'Sweden',
#    'Egypt',
#    'Yugoslavia',
#    'Poland',
#    'Ukraine',
#    'Serbia',
#    'Bosnia and Herzegovina',
#    'Pakistan',
#    'Croatia',
#    'Georgia',
#    'France',
#    'Germany',
#    'China',
#    'South Africa'],
#   180: ['India',
#    'Turkey',
#    'Romania',
#    'Hungary',
#    'United States',
#    'Bangladesh',
#    'Italy',
#    'Japan',
#    'Iran, Islamic Republic of',
#    'United Kingdom',
#    'Brazil',
#    'Egypt',
#    'Latvia',
#    'Canada',
#    'Yugoslavia',
#    'Germany',
#    'Czech Republic',
#    'Mexico',
#    'Sweden',
#    'Poland',
#    'Ukraine',
#    'Serbia',
#    'Bosnia and Herzegovina',
#    'Pakistan',
#    'Croatia',
#    'Georgia',
#    'France',
#    'China',
#    'South Africa'],
#   190: ['India',
#    'Turkey',
#    'Romania',
#    'Hungary',
#    'United States',
#    'Italy',
#    'Bangladesh',
#    'Japan',
#    'Iran, Islamic Republic of',
#    'Egypt',
#    'United Kingdom',
#    'Canada',
#    'Latvia',
#    'Brazil',
#    'Poland',
#    'France',
#    'Sweden',
#    'Germany',
#    'Czech Republic',
#    'Yugoslavia',
#    'Mexico',
#    'Ukraine',
#    'Bosnia and Herzegovina',
#    'Serbia',
#    'Pakistan',
#    'Croatia',
#    'Georgia',
#    'China',
#    'South Africa'],
#   200: ['India',
#    'Turkey',
#    'Romania',
#    'Hungary',
#    'Italy',
#    'Bangladesh',
#    'United States',
#    'Japan',
#    'Iran, Islamic Republic of',
#    'Egypt',
#    'Germany',
#    'Canada',
#    'Latvia',
#    'United Kingdom',
#    'Brazil',
#    'Poland',
#    'France',
#    'Czech Republic',
#    'Yugoslavia',
#    'Mexico',
#    'Sweden',
#    'Serbia',
#    'Ukraine',
#    'Bosnia and Herzegovina',
#    'Pakistan',
#    'Croatia',
#    'Georgia',
#    'Denmark',
#    'China',
#    'South Africa'],
#   146177: ['India',
#    'Italy',
#    'Turkey',
#    'Germany',
#    'France',
#    'South Korea',
#    'United States',
#    'Sweden',
#    'Iran, Islamic Republic of',
#    'Spain',
#    'Canada',
#    'Poland',
#    'Egypt',
#    'United Kingdom',
#    'Brazil',
#    'Japan',
#    'Denmark',
#    'Netherlands',
#    'Hungary',
#    'Norway',
#    'Mexico',
#    'Romania',
#    'Finland',
#    'Hong Kong',
#    'Indonesia',
#    'Australia',
#    'China',
#    'Philippines',
#    'Iceland',
#    'Czech Republic',
#    'Thailand',
#    'Bangladesh',
#    'Belgium',
#    'Portugal',
#    'Israel',
#    'Serbia',
#    'Croatia',
#    'South Africa',
#    'Argentina',
#    'Pakistan',
#    'Austria',
#    'Georgia',
#    'Singapore',
#    'United Arab Emirates',
#    'Lithuania',
#    'Yugoslavia',
#    'Latvia',
#    'Estonia',
#    'Saudi Arabia',
#    'Greece',
#    'Slovenia',
#    'Bosnia and Herzegovina',
#    'Russian Federation',
#    'Uruguay',
#    'Malaysia',
#    'Macedonia, The Former Yugoslav Republic of',
#    'Colombia',
#    'Ukraine',
#    'Viet Nam',
#    'Bhutan',
#    'Bulgaria',
#    'Kazakhstan',
#    'Myanmar',
#    'Armenia',
#    'Syrian Arab Republic',
#    'Uzbekistan',
#    'Albania',
#    'Slovakia',
#    'Honduras',
#    'Chile',
#    'Peru',
#    'Cyprus',
#    'Lebanon',
#    'Cambodia',
#    'Kyrgyzstan',
#    'Belarus']}}

# %%
rank = {}
for K in [10, 100, 1000]:
    print(f"Threshold: {K}")
    rank[K] = {}
    for N in range(10, 201, 10):
        pa = properAnalysis(df_analysis, K = K, N = N)
        rank[K][N] = pa[:min(10, len(pa))]
        print()
    print("-"*40)
# Out:
# Threshold: 10
# Top 10 countries - ranking
# 1. United States
# 2. Spain
# 3. India
# 4. Norway
# 5. El Salvador
# 6. Thailand
#
# Top 20 countries - ranking
# 1. United States
# 2. India
# 3. Spain
# 4. Brazil
# 5. Italy
# 6. Norway
# 7. El Salvador
# 8. Thailand
#
# Top 30 countries - ranking
# 1. United States
# 2. India
# 3. Brazil
# 4. Spain
# 5. Thailand
# 6. United Kingdom
# 7. Iran, Islamic Republic of
# 8. Italy
# 9. Norway
# 10. El Salvador
#
# Top 40 countries - ranking
# 1. United States
# 2. India
# 3. Thailand
# 4. Brazil
# 5. Spain
# 6. United Kingdom
# 7. Canada
# 8. Colombia
# 9. Iran, Islamic Republic of
# 10. Italy
#
# Top 50 countries - ranking
# 1. United States
# 2. India
# 3. Thailand
# 4. Brazil
# 5. Spain
# 6. United Kingdom
# 7. Italy
# 8. Canada
# 9. Colombia
# 10. Germany
#
# Top 60 countries - ranking
# 1. United States
# 2. India
# 3. Spain
# 4. Italy
# 5. Thailand
# 6. Brazil
# 7. United Kingdom
# 8. Canada
# 9. Colombia
# 10. Germany
#
# Top 70 countries - ranking
# 1. United States
# 2. India
# 3. Spain
# 4. Italy
# 5. Thailand
# 6. Brazil
# 7. Canada
# 8. United Kingdom
# 9. Iran, Islamic Republic of
# 10. Colombia
#
# Top 80 countries - ranking
# 1. United States
# 2. India
# 3. Spain
# 4. United Kingdom
# 5. Italy
# 6. Thailand
# 7. Brazil
# 8. Canada
# 9. Iran, Islamic Republic of
# 10. Colombia
#
# Top 90 countries - ranking
# 1. United States
# 2. India
# 3. Spain
# 4. Thailand
# 5. Italy
# 6. United Kingdom
# 7. Canada
# 8. Brazil
# 9. Iran, Islamic Republic of
# 10. Croatia
#
# Top 100 countries - ranking
# 1. United States
# 2. India
# 3. Spain
# 4. Brazil
# 5. United Kingdom
# 6. Italy
# 7. Thailand
# 8. Canada
# 9. Iran, Islamic Republic of
# 10. Germany
#
# Top 110 countries - ranking
# 1. United States
# 2. India
# 3. Spain
# 4. United Kingdom
# 5. Brazil
# 6. Thailand
# 7. Italy
# 8. Iran, Islamic Republic of
# 9. Canada
# 10. Germany
#
# Top 120 countries - ranking
# 1. United States
# 2. India
# 3. Spain
# 4. United Kingdom
# 5. Brazil
# 6. Thailand
# 7. Italy
# 8. Iran, Islamic Republic of
# 9. Germany
# 10. Canada
#
# Top 130 countries - ranking
# 1. United States
# 2. India
# 3. Spain
# 4. United Kingdom
# 5. Brazil
# 6. Thailand
# 7. Italy
# 8. Croatia
# 9. Indonesia
# 10. Iran, Islamic Republic of
#
# Top 140 countries - ranking
# 1. United States
# 2. India
# 3. Spain
# 4. United Kingdom
# 5. Thailand
# 6. Brazil
# 7. Italy
# 8. Iran, Islamic Republic of
# 9. Canada
# 10. Germany
#
# Top 150 countries - ranking
# 1. United States
# 2. India
# 3. Spain
# 4. United Kingdom
# 5. Thailand
# 6. Brazil
# 7. Italy
# 8. Iran, Islamic Republic of
# 9. Canada
# 10. Germany
#
# Top 160 countries - ranking
# 1. United States
# 2. India
# 3. United Kingdom
# 4. Spain
# 5. Thailand
# 6. Brazil
# 7. Italy
# 8. Indonesia
# 9. Iran, Islamic Republic of
# 10. Germany
#
# Top 170 countries - ranking
# 1. United States
# 2. India
# 3. United Kingdom
# 4. Spain
# 5. Thailand
# 6. Brazil
# 7. Italy
# 8. Indonesia
# 9. Iran, Islamic Republic of
# 10. Germany
#
# Top 180 countries - ranking
# 1. United States
# 2. India
# 3. United Kingdom
# 4. Spain
# 5. Brazil
# 6. Thailand
# 7. Italy
# 8. Germany
# 9. Iran, Islamic Republic of
# 10. Serbia
#
# Top 190 countries - ranking
# 1. United States
# 2. India
# 3. United Kingdom
# 4. Italy
# 5. Brazil
# 6. Spain
# 7. Thailand
# 8. Germany
# 9. Serbia
# 10. Iran, Islamic Republic of
#
# Top 200 countries - ranking
# 1. United States
# 2. India
# 3. United Kingdom
# 4. Spain
# 5. Brazil
# 6. Italy
# 7. Thailand
# 8. Germany
# 9. Iran, Islamic Republic of
# 10. Serbia
#
# ----------------------------------------
# Threshold: 100
# Top 10 countries - ranking
# 1. India
# 2. United States
#
# Top 20 countries - ranking
# 1. India
# 2. Bosnia and Herzegovina
# 3. United States
# 4. Germany
# 5. Spain
# 6. Serbia
#
# Top 30 countries - ranking
# 1. India
# 2. United States
# 3. Bosnia and Herzegovina
# 4. Serbia
# 5. Germany
# 6. Spain
# 7. Myanmar
#
# Top 40 countries - ranking
# 1. India
# 2. United States
# 3. Bosnia and Herzegovina
# 4. United Kingdom
# 5. Serbia
# 6. Brazil
# 7. Germany
# 8. Spain
# 9. Myanmar
#
# Top 50 countries - ranking
# 1. India
# 2. United States
# 3. United Kingdom
# 4. Bosnia and Herzegovina
# 5. Serbia
# 6. Albania
# 7. Bangladesh
# 8. Brazil
# 9. Costa Rica
# 10. Germany
#
# Top 60 countries - ranking
# 1. India
# 2. United States
# 3. United Kingdom
# 4. Bosnia and Herzegovina
# 5. Serbia
# 6. Albania
# 7. Bangladesh
# 8. Brazil
# 9. Costa Rica
# 10. Germany
#
# Top 70 countries - ranking
# 1. India
# 2. United States
# 3. United Kingdom
# 4. Bosnia and Herzegovina
# 5. Serbia
# 6. Albania
# 7. Argentina
# 8. Bangladesh
# 9. Brazil
# 10. Costa Rica
#
# Top 80 countries - ranking
# 1. India
# 2. United States
# 3. United Kingdom
# 4. Bosnia and Herzegovina
# 5. South Korea
# 6. Serbia
# 7. Bangladesh
# 8. Brazil
# 9. Canada
# 10. Costa Rica
#
# Top 90 countries - ranking
# 1. India
# 2. United States
# 3. United Kingdom
# 4. South Korea
# 5. Bangladesh
# 6. Serbia
# 7. Bosnia and Herzegovina
# 8. Costa Rica
# 9. Germany
# 10. Spain
#
# Top 100 countries - ranking
# 1. India
# 2. United States
# 3. United Kingdom
# 4. Bangladesh
# 5. South Korea
# 6. Italy
# 7. Serbia
# 8. Albania
# 9. Bosnia and Herzegovina
# 10. Costa Rica
#
# Top 110 countries - ranking
# 1. India
# 2. United States
# 3. United Kingdom
# 4. Bangladesh
# 5. South Korea
# 6. Italy
# 7. Serbia
# 8. Bosnia and Herzegovina
# 9. Albania
# 10. Costa Rica
#
# Top 120 countries - ranking
# 1. India
# 2. United States
# 3. United Kingdom
# 4. Serbia
# 5. Bangladesh
# 6. South Korea
# 7. Italy
# 8. Albania
# 9. Bosnia and Herzegovina
# 10. Costa Rica
#
# Top 130 countries - ranking
# 1. India
# 2. United States
# 3. United Kingdom
# 4. Serbia
# 5. Bangladesh
# 6. South Korea
# 7. Italy
# 8. Iran, Islamic Republic of
# 9. Albania
# 10. Bosnia and Herzegovina
#
# Top 140 countries - ranking
# 1. India
# 2. United States
# 3. United Kingdom
# 4. Serbia
# 5. Bangladesh
# 6. South Korea
# 7. Italy
# 8. Iran, Islamic Republic of
# 9. Albania
# 10. Bosnia and Herzegovina
#
# Top 150 countries - ranking
# 1. India
# 2. United States
# 3. United Kingdom
# 4. Bangladesh
# 5. Serbia
# 6. South Korea
# 7. Italy
# 8. Iran, Islamic Republic of
# 9. Albania
# 10. Bosnia and Herzegovina
#
# Top 160 countries - ranking
# 1. India
# 2. United States
# 3. United Kingdom
# 4. Bangladesh
# 5. Serbia
# 6. South Korea
# 7. Italy
# 8. Turkey
# 9. Iran, Islamic Republic of
# 10. Albania
#
# Top 170 countries - ranking
# 1. India
# 2. United States
# 3. United Kingdom
# 4. Bangladesh
# 5. Serbia
# 6. South Korea
# 7. Italy
# 8. Turkey
# 9. Iran, Islamic Republic of
# 10. Albania
#
# Top 180 countries - ranking
# 1. India
# 2. United States
# 3. United Kingdom
# 4. Bangladesh
# 5. Turkey
# 6. Serbia
# 7. South Korea
# 8. Italy
# 9. Iran, Islamic Republic of
# 10. Albania
#
# Top 190 countries - ranking
# 1. India
# 2. United States
# 3. United Kingdom
# 4. Bangladesh
# 5. Turkey
# 6. Italy
# 7. Serbia
# 8. South Korea
# 9. Iran, Islamic Republic of
# 10. Albania
#
# Top 200 countries - ranking
# 1. India
# 2. United States
# 3. United Kingdom
# 4. Turkey
# 5. Bangladesh
# 6. Italy
# 7. Serbia
# 8. South Korea
# 9. Lithuania
# 10. Iran, Islamic Republic of
#
# ----------------------------------------
# Threshold: 1000
# Top 10 countries - ranking
# 1. India
# 2. Bangladesh
# 3. Croatia
#
# Top 20 countries - ranking
# 1. India
# 2. Bangladesh
# 3. Turkey
# 4. Canada
# 5. Finland
# 6. Croatia
# 7. Latvia
#
# Top 30 countries - ranking
# 1. India
# 2. Bangladesh
# 3. Turkey
# 4. Hungary
# 5. Latvia
# 6. Canada
# 7. Finland
# 8. Croatia
# 9. Romania
# 10. Yugoslavia
#
# Top 40 countries - ranking
# 1. India
# 2. Turkey
# 3. Bangladesh
# 4. Hungary
# 5. Romania
# 6. Finland
# 7. Latvia
# 8. Canada
# 9. Germany
# 10. Croatia
#
# Top 50 countries - ranking
# 1. India
# 2. Turkey
# 3. Bangladesh
# 4. Romania
# 5. Hungary
# 6. Finland
# 7. Latvia
# 8. Canada
# 9. Germany
# 10. Croatia
#
# Top 60 countries - ranking
# 1. India
# 2. Turkey
# 3. Bangladesh
# 4. Romania
# 5. Hungary
# 6. Finland
# 7. Croatia
# 8. Latvia
# 9. Canada
# 10. Germany
#
# Top 70 countries - ranking
# 1. India
# 2. Turkey
# 3. Bangladesh
# 4. Hungary
# 5. Romania
# 6. Finland
# 7. Croatia
# 8. Latvia
# 9. Canada
# 10. Germany
#
# Top 80 countries - ranking
# 1. India
# 2. Turkey
# 3. Romania
# 4. Bangladesh
# 5. Hungary
# 6. Latvia
# 7. Yugoslavia
# 8. Croatia
# 9. Finland
# 10. Canada
#
# Top 90 countries - ranking
# 1. India
# 2. Turkey
# 3. Romania
# 4. Bangladesh
# 5. Hungary
# 6. United States
# 7. Latvia
# 8. Yugoslavia
# 9. Croatia
# 10. Finland
#
# Top 100 countries - ranking
# 1. India
# 2. Turkey
# 3. Hungary
# 4. Romania
# 5. Bangladesh
# 6. Croatia
# 7. United States
# 8. Finland
# 9. Latvia
# 10. Yugoslavia
#
# Top 110 countries - ranking
# 1. India
# 2. Turkey
# 3. Romania
# 4. Hungary
# 5. Bangladesh
# 6. United States
# 7. Croatia
# 8. Latvia
# 9. Yugoslavia
# 10. Finland
#
# Top 120 countries - ranking
# 1. India
# 2. Turkey
# 3. Romania
# 4. Hungary
# 5. Bangladesh
# 6. United States
# 7. Croatia
# 8. Japan
# 9. Latvia
# 10. Italy
#
# Top 130 countries - ranking
# 1. India
# 2. Turkey
# 3. Romania
# 4. Bangladesh
# 5. Hungary
# 6. United States
# 7. Japan
# 8. Croatia
# 9. Italy
# 10. Yugoslavia
#
# Top 140 countries - ranking
# 1. India
# 2. Turkey
# 3. Romania
# 4. Hungary
# 5. Bangladesh
# 6. United States
# 7. Japan
# 8. Italy
# 9. Canada
# 10. Croatia
#
# Top 150 countries - ranking
# 1. India
# 2. Turkey
# 3. Romania
# 4. Bangladesh
# 5. Hungary
# 6. Japan
# 7. United States
# 8. Italy
# 9. Canada
# 10. Latvia
#
# Top 160 countries - ranking
# 1. India
# 2. Turkey
# 3. Romania
# 4. Italy
# 5. Hungary
# 6. Bangladesh
# 7. United States
# 8. Japan
# 9. Canada
# 10. Latvia
#
# Top 170 countries - ranking
# 1. India
# 2. Turkey
# 3. Italy
# 4. Romania
# 5. Hungary
# 6. Bangladesh
# 7. United States
# 8. Japan
# 9. Canada
# 10. Latvia
#
# Top 180 countries - ranking
# 1. India
# 2. Turkey
# 3. Italy
# 4. Romania
# 5. Hungary
# 6. United States
# 7. Bangladesh
# 8. Japan
# 9. Croatia
# 10. Iran, Islamic Republic of
#
# Top 190 countries - ranking
# 1. India
# 2. Turkey
# 3. Romania
# 4. Italy
# 5. Hungary
# 6. Bangladesh
# 7. United States
# 8. Japan
# 9. Croatia
# 10. Egypt
#
# Top 200 countries - ranking
# 1. India
# 2. Turkey
# 3. Romania
# 4. Italy
# 5. Hungary
# 6. United States
# 7. Bangladesh
# 8. Japan
# 9. Croatia
# 10. Iran, Islamic Republic of
#
# ----------------------------------------
